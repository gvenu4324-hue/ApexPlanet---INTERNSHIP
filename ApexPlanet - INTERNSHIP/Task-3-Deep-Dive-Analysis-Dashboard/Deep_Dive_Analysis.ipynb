# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\David Chua\Desktop\INTERNSHIP\Task-2-EDA\cleaned_dataset.csv.csv")
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          Unknown
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          Unknown
# 4      s5  TV Show           Kota Factory          Unknown
#
#                                                 cast        country  \
# 0                                      Not Available  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
# 3                                      Not Available        Unknown
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#    date_added  release_year rating   duration  \
# 0  2021-09-25          2020  PG-13     90 min
# 1  2021-09-24          2021  TV-MA  2 Seasons
# 2  2021-09-24          2021  TV-MA   1 Season
# ...

# %% [markdown]
# # KPI 1: Total Titles
# Formula:
# COUNT(show_id)
# Business Meaning:
# Total content available on Netflix.
#
# KPI 2: Movie Percentage
# Formula:
# Movies / Total Titles × 100
# Business Meaning:
# Measures movie dominance.
#
# KPI 3: Top Country Contribution
# Formula:
# Country Titles / Total Titles × 100
# Business Meaning:
# Measures geographic dominance.
#
# KPI 4: Mature Audience Content
# Formula:
# TV-MA / Total Titles × 100
# Business Meaning:
# Measures mature audience targeting.
#
# KPI 5: Peak Production Year
# Formula:
# Year with highest number of titles
# Business Meaning:
# Measures growth trend.

# %%
total_titles = len(df)
print(total_titles)
movie_percentage = (6131/8807)*100
print(movie_percentage)
country_percentage = (2818/8807)*100
print(country_percentage)
mature_percentage = (3207/8807)*100
print(mature_percentage)
df['release_year'].value_counts().idxmax()
# Out:
# 8807
# 69.61507891449983
# 31.997274894969912
# 36.41421596457363
# np.int64(2018)

# %%
kpi_data = {
    "KPI": [
        "Total Titles",
        "Movie Percentage",
        "US Contribution",
        "TV-MA Percentage",
        "Peak Production Year"
    ],
    "Value": [
        8807,
        "69.6%",
        "31.99%",
        "36.41%",
        2018
    ]
}
kpi_df = pd.DataFrame(kpi_data)
kpi_df
# Out:
#                     KPI   Value
# 0          Total Titles    8807
# 1      Movie Percentage   69.6%
# 2       US Contribution  31.99%
# 3      TV-MA Percentage  36.41%
# 4  Peak Production Year    2018

# %% [markdown]
# # KPI Results
#
# | KPI | Value |
# |-----|-----|
# | Total Titles | 8807 |
# | Movie Percentage | 69.6% |
# | US Contribution | 31.99% |
# | TV-MA Percentage | 36.41% |
# | Peak Production Year | 2018 |

# %% [markdown]
# # Deep-Dive Analysis 1: Content Growth Trend
#
# Objective:
# Analyze how Netflix content production changed over time.

# %%
import matplotlib.pyplot as plt
year_counts = df['release_year'].value_counts().sort_index()
plt.figure(figsize=(12,5))
year_counts.plot(kind='line', marker='o')
plt.title('Netflix Content Growth Trend')
plt.xlabel('Release Year')
plt.ylabel('Number of Titles')
plt.show()

# %% [markdown]
# ### Insight
#
# Netflix content production increased rapidly between 2012 and 2018.
# The highest number of titles was released in 2018.
# After 2018, content growth declined gradually.

# %% [markdown]
# # Deep-Dive Analysis 2: Audience Analysis
#
# Objective:
# Analyze which audience groups Netflix targets.

# %%
rating_counts = df['rating'].value_counts().head(10)
plt.figure(figsize=(10,5))
rating_counts.plot(kind='bar')
plt.title('Audience Rating Distribution')
plt.xlabel('Rating')
plt.ylabel('Number of Titles')
plt.show()

# %% [markdown]
# ### Insight
#
# Netflix primarily targets mature audiences.
# TV-MA and TV-14 content dominate the platform.

# %% [markdown]
# # Deep-Dive Analysis 3: Geographic Analysis
#
# Objective:
# Analyze geographic distribution of Netflix content.

# %%
top_countries = df['country'].value_counts().head(10)
plt.figure(figsize=(10,5))
top_countries.plot(kind='bar')
plt.title('Top Content Producing Countries')
plt.xlabel('Country')
plt.ylabel('Number of Titles')
plt.show()

# %% [markdown]
# ### Insight
#
# The United States dominates Netflix content production,
# followed by India and the United Kingdom.
